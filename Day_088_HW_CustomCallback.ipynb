# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import keras

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
  input_layer = keras.layers.Input(input_shape)
  
  for i, n_units in enumerate(num_neurons):
      if i == 0:
          x = keras.layers.Dense(units=n_units, 
                                  activation="relu", 
                                  name="hidden_layer"+str(i+1))(input_layer)
          x = BatchNormalization()(x)
      else:
          x = keras.layers.Dense(units=n_units, 
                                  activation="relu", 
                                  name="hidden_layer"+str(i+1))(x)
          x = BatchNormalization()(x)
  
  out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
  
  model = keras.models.Model(inputs=[input_layer], outputs=[out])
  return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 256
MOMENTUM = 0.95

# %%
from keras.callbacks import Callback

"""Code Here
撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
"""

class Record_tp_tn(Callback):
    
  def __init__(self, val_data=(x_test, y_test)):
    self.validation_data = val_data
  
  def on_train_begin(self, epoch, logs={}):
    logs = logs or {}
    record_items = ["val_tp", "val_tn"]
    for i in record_items:
        try:
          if i not in self.params['metrics']:
            self.params['metrics'].append(i)
        except:
          self.params['metrics'] = i

  def on_epoch_end(self, epoch, logs={}, thres=0.5):
    logs = logs or {}
    y_true = self.validation_data[1].argmax(axis = 1)
    y_pred = self.model.predict(self.validation_data[0])
    y_pred = (y_pred[:, 1] >= thres) * 1
    
    tp = keras.metrics.TruePositives()
    tp.reset_states()
    tp.update_state(y_true, y_pred)
    logs['val_tp'] = tp.result()
    
    tn = keras.metrics.TrueNegatives()
    tn.reset_states()
    tn.update_state(y_true, y_pred)
    logs['val_tn'] = tn.result()
    

        
rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(
    x_train, y_train, 
    epochs=EPOCHS, 
    batch_size=BATCH_SIZE, 
    validation_data=(x_test, y_test), 
    shuffle=True,
    callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/25
# 196/196 [==============================] - 2s 8ms/step - loss: 2.0759 - accuracy: 0.2990 - val_loss: 1.7305 - val_accuracy: 0.3882
# Epoch 2/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.5581 - accuracy: 0.4532 - val_loss: 1.5685 - val_accuracy: 0.4421
# Epoch 3/25
# 196/196 [==============================] - 1s 5ms/step - loss: 1.4457 - accuracy: 0.4900 - val_loss: 1.5831 - val_accuracy: 0.4364
# Epoch 4/25
# 196/196 [==============================] - 1s 5ms/step - loss: 1.3569 - accuracy: 0.5238 - val_loss: 1.5181 - val_accuracy: 0.4620
# Epoch 5/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.3057 - accuracy: 0.5419 - val_loss: 1.4974 - val_accuracy: 0.4717
# Epoch 6/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.2579 - accuracy: 0.5611 - val_loss: 1.5815 - val_accuracy: 0.4469
# Epoch 7/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.2086 - accuracy: 0.5765 - val_loss: 1.5576 - val_accuracy: 0.4627
# Epoch 8/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.1657 - accuracy: 0.5908 - val_loss: 1.4715 - val_accuracy: 0.4902
# Epoch 9/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.1210 - accuracy: 0.6069 - val_loss: 1.4777 - val_accuracy: 0.4828
# Epoch 10/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.0877 - accuracy: 0.6206 - val_loss: 1.5387 - val_accuracy: 0.4742
# Epoch 11/25
# 196/196 [==============================] - 1s 6ms/step - loss: 1.0454 - accuracy: 0.6364 - val_loss: 1.5051 - val_accuracy: 0.4870
# Epoch 12/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.9932 - accuracy: 0.6573 - val_loss: 1.5221 - val_accuracy: 0.4816
# Epoch 13/25
# 196/196 [==============================] - 1s 5ms/step - loss: 0.9707 - accuracy: 0.6665 - val_loss: 1.4683 - val_accuracy: 0.4944
# Epoch 14/25
# 196/196 [==============================] - 1s 5ms/step - loss: 0.9413 - accuracy: 0.6757 - val_loss: 1.5011 - val_accuracy: 0.4861
# Epoch 15/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.8985 - accuracy: 0.6912 - val_loss: 1.5706 - val_accuracy: 0.4777
# Epoch 16/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.8676 - accuracy: 0.7034 - val_loss: 1.6190 - val_accuracy: 0.4734
# Epoch 17/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.8264 - accuracy: 0.7196 - val_loss: 1.7125 - val_accuracy: 0.4613
# Epoch 18/25
# 196/196 [==============================] - 1s 5ms/step - loss: 0.8050 - accuracy: 0.7238 - val_loss: 1.5899 - val_accuracy: 0.4769
# Epoch 19/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.7730 - accuracy: 0.7359 - val_loss: 1.6457 - val_accuracy: 0.4775
# Epoch 20/25
# 196/196 [==============================] - 1s 5ms/step - loss: 0.7350 - accuracy: 0.7517 - val_loss: 1.6352 - val_accuracy: 0.4769
# Epoch 21/25
# 196/196 [==============================] - 1s 5ms/step - loss: 0.7233 - accuracy: 0.7546 - val_loss: 1.6374 - val_accuracy: 0.4914
# Epoch 22/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.6795 - accuracy: 0.7718 - val_loss: 1.7029 - val_accuracy: 0.4746
# Epoch 23/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.6523 - accuracy: 0.7817 - val_loss: 1.6820 - val_accuracy: 0.4783
# Epoch 24/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.6269 - accuracy: 0.7901 - val_loss: 1.7918 - val_accuracy: 0.4601
# Epoch 25/25
# 196/196 [==============================] - 1s 6ms/step - loss: 0.6025 - accuracy: 0.8018 - val_loss: 1.7560 - val_accuracy: 0.4763

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
