# %% [markdown]
# # 作業
# 今天的作業希望大家能夠看看全球機器學習巨頭們在做的機器學習專案。以 google 為例，下圖是 Google 內部專案使用機器學習的數量，隨著時間進展，現在早已超過 2000 個專案在使用機器學習。
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
'''
文章: Unsupervised Translation of Programming Languages
(https://research.fb.com/publications/)


1. 專案的目標？ 
 - 讓高階的程式語言 (e.g. C++, Python, Java) 間能隨意轉換 (Source-to-source translation)
 - 把舊版本的語言轉換成現在較新的版本語言 ( e.g. COBOL, Python 2)


2. 使用的技術是？ 
   unsupervised machine translation
   (sequence-to-sequence (seq2seq) model with attention)

3. 資料來源？
   Github

'''
